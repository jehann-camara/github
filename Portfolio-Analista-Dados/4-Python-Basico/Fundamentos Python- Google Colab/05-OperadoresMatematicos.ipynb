# %%
# Operadores Matemativos

# %%
# Adição
2 + 5
# Out:
# 7

# %%
# Subtração
-7 - 5
# Out:
# -12

# %%
# Multiplicação
a = 47
b = 38
a*b + a
# Out:
# 1833

# %%
# Divisão
a= 47
b=8
a / b
# Out:
# 5.875

# %%
# Módulo = o resto da divisão
5 % 2
# Out:
# 1

# %%
8 % 2
# Out:
# 0

# %%
# Potenciacao
2**3
# Out:
# 8

# %%
int(3.14)
# Out:
# 3

# %%
float(5)
# Out:
# 5.0
