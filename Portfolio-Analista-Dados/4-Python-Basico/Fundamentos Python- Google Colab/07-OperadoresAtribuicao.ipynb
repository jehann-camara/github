# %%
x = 10 # = é usado como atribuicao e nao igualdade, diferente de ==

# %%
x = x + 5

# %%
x
# Out:
# 15

# %%
x += 5 # é igual a x = x + 5

# %%
x
# Out:
# 20

# %%
x -= 12

# %%
x
# Out:
# 8

# %%
# Multiplicação
x *= 7  # é igual a x = x * 7

# %%
x
# Out:
# 56

# %%
x /= 2 # Mesma Lógica

# %%
x
# Out:
# 28.0

# %%
x **= 3 # é igual a x = x ** 3
x
# Out:
# 21952.0
