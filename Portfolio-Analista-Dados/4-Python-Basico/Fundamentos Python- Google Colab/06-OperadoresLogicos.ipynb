# %%
# Igualdade
5 == 5
# Out:
# True

# %%
5 == 7
# Out:
# False

# %%
# Desigualdade
5 != 5
# Out:
# False

# %%
5 != 7
# Out:
# True

# %%
# Maior que
5 > 2
# Out:
# True

# %%
# Menor que
7 < 5
# Out:
# False

# %%
# Maior ou Igual
5 >= 7
# Out:
# False

# %%
# Menor ou Igual
5 <= 7
# Out:
# True
