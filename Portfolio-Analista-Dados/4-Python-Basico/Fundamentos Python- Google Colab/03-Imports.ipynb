# %%
import math # Importa biblioteca

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
from math import sqrt, cos # Import funcoes especificas de Math para serem usadas diretamente

# %%
sqrt(100)
# Out:
# 10.0

# %%
cos(6)
# Out:
# 0.960170286650366

# %%
from math import * # Importa todas as funcoes de Math

# %%
sin(4) + floor(5.34)
# Out:
# 4.243197504692072

# %%
factorial(6)
# Out:
# 720
