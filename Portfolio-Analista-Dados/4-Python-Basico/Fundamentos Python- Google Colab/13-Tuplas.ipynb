# %%
# Tuplas / não são mutáveis

lista = []
dicionario = {}
tupla = ()

# %%
tupla1 = (1,2,3,4,5,6)

# %%
tupla1.count(3) # Return number of occurrences of value.
# Out:
# 1

# %%
# [] geralmente é relacionado ao indice/index de uma estrutura de dados, ex:
tupla1[3]
# Out:
# 4

# %%
# nao se deleta tupla, por ser imutavel, ex :
del tupla1[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-030932faf7a3> in <module>
#       1 # nao se deleta tupla, por ser imutavel, ex :
# ----> 2 del tupla1[3]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
# Para as Tuplas os () não são obrigatórios, ex:
tupla2 = "a","b","c","d"

# %%
type(tupla2)
# Out:
# tuple

# %%
# Para "alterar" uma tupla

# %%
tupla3 = (1,2,3,4,5)

# %%
lista = list(tupla3) # Passou a tupla para uma lista

# %%
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
lista.append(6) # adiciona um elemento/indice

# %%
tupla3 = tuple(lista) # Passa a lista para a tupla de volta

# %%
tupla3
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
type(tupla3)
# Out:
# tuple
