# %%
# Listas
l1 = [] # Lista Vazia / usando colchetes

# %%
type(l1)
# Out:
# list

# %%
l2 = list() # usando parenteses

# %%
type(l2)
# Out:
# list

# %%
n1 = ['Jehann', 'Jacks', 'Jeann']

# %%
n2 = ['Jehann, Jacks, Jeann']

# %%
n1
# Out:
# ['Jehann', 'Jacks', 'Jeann']

# %%
n2
# Out:
# ['Jehann, Jacks, Jeann']

# %%
len(n1)
# Out:
# 3

# %%
len(n2)
# Out:
# 1

# %%
n2[0]
# Out:
# 'Jehann, Jacks, Jeann'

# %%
n1[0]
# Out:
# 'Jehann'

# %%
n1[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-81a1e64dfc55> in <module>
# ----> 1 n1[3]
#
# IndexError: list index out of range

# %%
n2[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-b018892fb3b4> in <module>
# ----> 1 n2[1]
#
# IndexError: list index out of range

# %%
n1[0:1]
# Out:
# ['Jehann']

# %%
n1.insert(3,"Lucas")

# %%
n1
# Out:
# ['Jehann', 'Jacks', 'Jeann', 'Lucas']

# %%
n1.append("João")

# %%
n1
# Out:
# ['Jehann', 'Jacks', 'Jeann', 'Lucas', 'João']

# %%
listaMista = ['Jehann', 6 , 'Jeann', 5.5]
listaMista
# Out:
# ['Jehann', 6, 'Jeann', 5.5]

# %%
type(listaMista)
# Out:
# list

# %%
type(listaMista[3])
# Out:
# float

# %%
# Deletar elementos de uma lista

# %%
del n1[2] # usanso o del

# %%
n1
# Out:
# ['Jehann', 'Jacks', 'Lucas', 'João']

# %%
n1.remove("João") # usando o remove

# %%
n1
# Out:
# ['Jehann', 'Jacks', 'Lucas']

# %%
# Listas aninhadas

# %%
lista1 = [[11,22,33], [1,2,3,4], [100,200,300,400,500]]

# %%
type(lista1)
# Out:
# list

# %%
lista1[0]
# Out:
# [11, 22, 33]

# %%
lista1[0][1]
# Out:
# 22

# %%
lista1[2][3]
# Out:
# 400

# %%
# Junção de listas e avaliação de elementos

l1 = [1,2,3,4,5]

# %%
l2 = [22,33,44,55,66,77]

# %%
soma = l1 + l2

# %%
soma
# Out:
# [1, 2, 3, 4, 5, 22, 33, 44, 55, 66, 77]

# %%
# perguntas

# %%
20 in soma
# Out:
# False

# %%
22 in soma or l1
# Out:
# True

# %%
soma.count(5) # so existe um elemento 5
# Out:
# 1

# %%
soma.append(5)

# %%
soma.append("5")

# %%
soma
# Out:
# [1, 2, 3, 4, 5, 22, 33, 44, 55, 66, 77, 5, '5']

# %%
soma.count(5) # existe a diferenciação entre o 5 tipo int e tipo string
# Out:
# 1

# %%
soma.count("5")
# Out:
# 1

# %%
soma.index(55) # mostra a posicao do elemento
# Out:
# 8

# %%
soma[soma.index(55)]
# Out:
# 55

# %%
soma.insert(6,777)

# %%
soma
# Out:
# [1, 2, 3, 4, 5, 5, 22, 33, 44, 55, 66, 77, 777]

# %%
soma.sort() # Ordena os elemntos da lista

# %%
soma
# Out:
# [1, 2, 3, 4, 5, 5, 22, 33, 44, 55, 66, 77, 777]

# %%
soma.reverse() # ordena reverso

# %%
soma
# Out:
# [777, 77, 66, 55, 44, 33, 22, 5, 5, 4, 3, 2, 1]

# %%
# Cópia e referenciação de listas atenção

# %%
lista1 = [11,22,33,44,55,66,]
lista2 = lista1

# %%
lista2.append(1)

# %%
lista2
# Out:
# [11, 22, 33, 44, 55, 66, 1]

# %%
lista1
# Out:
# [11, 22, 33, 44, 55, 66, 1]

# %%
# !!! Tudo feito em lista 2 ocorre em lista 1 espelhado, pois foi feita referencia e nao cópia de listas.

# %%
# Copia de listas
lista3 = lista2[:]

# %%
lista3.append(8)

# %%
lista3
# Out:
# [11, 22, 33, 44, 55, 66, 1, 8]

# %%
lista1
# Out:
# [11, 22, 33, 44, 55, 66, 1]

# %%
# Copia de listas
lista4 = lista3.copy()

# %%
lista4.append(99)

# %%
#resultado

# %%
lista1
# Out:
# [11, 22, 33, 44, 55, 66, 1]

# %%
lista2
# Out:
# [11, 22, 33, 44, 55, 66, 1]

# %%
lista3
# Out:
# [11, 22, 33, 44, 55, 66, 1, 8]

# %%
lista4
# Out:
# [11, 22, 33, 44, 55, 66, 1, 8, 99]
