# %%
### Sempre resetar/compilar as células caso tenha modificações

# Nao pode utilizar uma variavel iniciando com numero Ex:
#5f = 35
f5 = 35

# %%
# Não pode utilizar os seguintes caracteres : "",<>/|\()@#&$^*+-!

# %%
#*h5 = 40
h5 = 40

# %%
# Palavras reservadas no Python:
'''True,False,class,finally,is,return,None,continue,for
lambda,try,except,def,from,nonlocal,While,and,del,global
not,with,in,as,elif,if,Or,yield,Asasert,Else,import,pass,break,raise'''
# Out:
# 'True,False,class,finally,is,return,None,continue,for\nlambda,try,except,def,from,nonlocal,While,and,del,global\nnot,with,in,as,elif,if,Or,yield,Asasert,Else,import,pass,break,raise'

# %%
# Python é case sensitive e Tipagem dinâmica

# %%
# Variaveis Inteiras
Var_a = 13

# %%
var_a = Var_a + 5

# %%
var_a
# Out:
# 18

# %%
type(var_a)
# Out:
# int

# %%
# Float(4 bytes) e Double(8 bytes)
var_c = 3.14

# %%
type(var_c)
# Out:
# float

# %%
# Variaveis Strings
s1="Jehann "

# %%
type(s1)
# Out:
# str

# %%
s2='aspas simples'

# %%
s3= s1+s2

# %%
s3
# Out:
# 'Jehann aspas simples'

# %%
# Variaveis Booleanas

h = True # Em maiusculo

# %%
type(h)
# Out:
# bool

# %%
# Declarações Multiplas

d1,d2,d3 = "Matemática","Física","Química"

# %%
d1
d2
d3
# Out:
# 'Química'

# %%
d1
# Out:
# 'Matemática'

# %%
d2
# Out:
# 'Física'

# %%
g1 =g2 =g3 = "Python"

# %%
g1
# Out:
# 'Python'

# %%
g2
# Out:
# 'Python'

# %%
g3
# Out:
# 'Python'

# %%
idade , nome, vivo = 18, "Jehann", True

# %%
vivo
# Out:
# True

# %%
# Principais Erros de declarações


# Não pode começar variável com número, ex:
#8a = 15
a8 = 15

# %%
# Booleano precisa ser True ou False
#True = 77

# %%
#class = 3.5

# %%
a = 10
b = 3

# %%
v = a/b

# %%
type(v)
# Out:
# float

# %%
a % b # Resto da divisao
# Out:
# 1

# %%
p = "Python "

# %%
p + a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 p + a
#
# TypeError: can only concatenate str (not "int") to str

# %%
p + str(a)
# Out:
# 'Python 10'

# %%
### Sempre resetar as células caso tenha modificações
