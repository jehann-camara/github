# %% [markdown]
# Primeiro script Python Pandas

# %%
import numpy as np
import pandas as pd

datas = pd.date_range(20250101, periods = 6, freq="D")
datas
# Out:
# DatetimeIndex(['1970-01-01 00:00:00.020250101',
#                '1970-01-02 00:00:00.020250101',
#                '1970-01-03 00:00:00.020250101',
#                '1970-01-04 00:00:00.020250101',
#                '1970-01-05 00:00:00.020250101',
#                '1970-01-06 00:00:00.020250101'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Dataframes

df = pd.DataFrame(np.random.randn(6,4), index= datas, columns= list("ABCD"))
df
# Out:
#                                       A         B         C         D
# 1970-01-01 00:00:00.020250101  0.248395  1.168314  0.416974 -0.558783
# 1970-01-02 00:00:00.020250101  1.122472  0.276825  0.068356  0.766121
# 1970-01-03 00:00:00.020250101  1.165734 -0.112565 -1.616218 -0.711604
# 1970-01-04 00:00:00.020250101 -1.499234  0.736886  0.685379 -0.362600
# 1970-01-05 00:00:00.020250101 -0.333834  1.545992 -0.380351  2.485251
# 1970-01-06 00:00:00.020250101 -0.605451  1.052152  1.194089  0.261396

# %%
type(df
     )
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.DataFrame({"A":7,
                     "B": pd.Timestamp('20250101'),
                     "C":pd.Series(1, index = list(range(4)), dtype= "float32"), 
                     "D": np.array([3] * 4, dtype='int32'),
                     "E": pd.Categorical(["teste", "Train","Teste", "Train"]),
                     "F": "Python" }

)

df2
# Out:
#    A          B    C  D      E       F
# 0  7 2025-01-01  1.0  3  teste  Python
# 1  7 2025-01-01  1.0  3  Train  Python
# 2  7 2025-01-01  1.0  3  Teste  Python
# 3  7 2025-01-01  1.0  3  Train  Python

# %%
df2.dtypes
# Out:
# A            int64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
import numpy as np
import pandas as pd

# DataFrame com 60 linhas  ( Adicionando Colunas )
datas = pd.date_range(20250101, periods = 60, freq="D")
df = pd.DataFrame(np.random.randn(60,5), index= datas, columns= list("ABCDE"))
#df.shape
df
# Out:
#                                       A         B         C         D  \
# 1970-01-01 00:00:00.020250101  0.831664 -0.282845 -0.542035  1.060830
# 1970-01-02 00:00:00.020250101 -0.167221 -0.114358  0.570631 -0.874840
# 1970-01-03 00:00:00.020250101 -1.077165  1.489998  0.982820 -0.101213
# 1970-01-04 00:00:00.020250101  1.271209 -0.691593 -0.343296  3.289127
# 1970-01-05 00:00:00.020250101  0.838642 -1.537191 -1.055967 -0.533710
# 1970-01-06 00:00:00.020250101  1.248819 -0.463632 -0.354111 -0.202749
# 1970-01-07 00:00:00.020250101  0.081499  1.460779 -0.918272 -0.471575
# 1970-01-08 00:00:00.020250101  0.525254 -0.381797  0.967154  1.533489
# 1970-01-09 00:00:00.020250101 -0.876179  0.272545 -1.143696 -0.805124
# 1970-01-10 00:00:00.020250101 -1.747875 -0.517902  0.784855  1.709248
# 1970-01-11 00:00:00.020250101  0.105785 -1.143431  0.635537  0.343618
# 1970-01-12 00:00:00.020250101 -1.191874  0.003139 -0.283662 -0.890903
# ...

# %%
df["F"] = 1 # repete o elemento 1 nas 60 linhas

# %%
df["G"] = range(60) # Mesmo range, número de linhas do df anterior

# %%
df
# Out:
#                                       A         B         C         D  \
# 1970-01-01 00:00:00.020250101  0.831664 -0.282845 -0.542035  1.060830
# 1970-01-02 00:00:00.020250101 -0.167221 -0.114358  0.570631 -0.874840
# 1970-01-03 00:00:00.020250101 -1.077165  1.489998  0.982820 -0.101213
# 1970-01-04 00:00:00.020250101  1.271209 -0.691593 -0.343296  3.289127
# 1970-01-05 00:00:00.020250101  0.838642 -1.537191 -1.055967 -0.533710
# 1970-01-06 00:00:00.020250101  1.248819 -0.463632 -0.354111 -0.202749
# 1970-01-07 00:00:00.020250101  0.081499  1.460779 -0.918272 -0.471575
# 1970-01-08 00:00:00.020250101  0.525254 -0.381797  0.967154  1.533489
# 1970-01-09 00:00:00.020250101 -0.876179  0.272545 -1.143696 -0.805124
# 1970-01-10 00:00:00.020250101 -1.747875 -0.517902  0.784855  1.709248
# 1970-01-11 00:00:00.020250101  0.105785 -1.143431  0.635537  0.343618
# 1970-01-12 00:00:00.020250101 -1.191874  0.003139 -0.283662 -0.890903
# ...

# %%
df.head((15)) # Os 15 primeiros do Dataframe
# Out:
#                                       A         B         C         D  \
# 1970-01-01 00:00:00.020250101  0.831664 -0.282845 -0.542035  1.060830
# 1970-01-02 00:00:00.020250101 -0.167221 -0.114358  0.570631 -0.874840
# 1970-01-03 00:00:00.020250101 -1.077165  1.489998  0.982820 -0.101213
# 1970-01-04 00:00:00.020250101  1.271209 -0.691593 -0.343296  3.289127
# 1970-01-05 00:00:00.020250101  0.838642 -1.537191 -1.055967 -0.533710
# 1970-01-06 00:00:00.020250101  1.248819 -0.463632 -0.354111 -0.202749
# 1970-01-07 00:00:00.020250101  0.081499  1.460779 -0.918272 -0.471575
# 1970-01-08 00:00:00.020250101  0.525254 -0.381797  0.967154  1.533489
# 1970-01-09 00:00:00.020250101 -0.876179  0.272545 -1.143696 -0.805124
# 1970-01-10 00:00:00.020250101 -1.747875 -0.517902  0.784855  1.709248
# 1970-01-11 00:00:00.020250101  0.105785 -1.143431  0.635537  0.343618
# 1970-01-12 00:00:00.020250101 -1.191874  0.003139 -0.283662 -0.890903
# ...

# %%
df["Produto"] = df["A"] * df["B"] # Adicionandop nova coluna que é o produto da coluna A e B

# %%
df.head(3)
# Out:
#                                       A         B         C         D  \
# 1970-01-01 00:00:00.020250101  0.831664 -0.282845 -0.542035  1.060830
# 1970-01-02 00:00:00.020250101 -0.167221 -0.114358  0.570631 -0.874840
# 1970-01-03 00:00:00.020250101 -1.077165  1.489998  0.982820 -0.101213
#
#                                       E  F  G   Produto
# 1970-01-01 00:00:00.020250101 -0.599378  1  0 -0.235232
# 1970-01-02 00:00:00.020250101 -1.329998  1  1  0.019123
# 1970-01-03 00:00:00.020250101  0.233243  1  2 -1.604974

# %%
df
# Out:
#                                       A         B         C         D  \
# 1970-01-01 00:00:00.020250101  0.831664 -0.282845 -0.542035  1.060830
# 1970-01-02 00:00:00.020250101 -0.167221 -0.114358  0.570631 -0.874840
# 1970-01-03 00:00:00.020250101 -1.077165  1.489998  0.982820 -0.101213
# 1970-01-04 00:00:00.020250101  1.271209 -0.691593 -0.343296  3.289127
# 1970-01-05 00:00:00.020250101  0.838642 -1.537191 -1.055967 -0.533710
# 1970-01-06 00:00:00.020250101  1.248819 -0.463632 -0.354111 -0.202749
# 1970-01-07 00:00:00.020250101  0.081499  1.460779 -0.918272 -0.471575
# 1970-01-08 00:00:00.020250101  0.525254 -0.381797  0.967154  1.533489
# 1970-01-09 00:00:00.020250101 -0.876179  0.272545 -1.143696 -0.805124
# 1970-01-10 00:00:00.020250101 -1.747875 -0.517902  0.784855  1.709248
# 1970-01-11 00:00:00.020250101  0.105785 -1.143431  0.635537  0.343618
# 1970-01-12 00:00:00.020250101 -1.191874  0.003139 -0.283662 -0.890903
# ...

# %%
df
# Out:
#                                       A         B         C         D  \
# 1970-01-01 00:00:00.020250101  0.831664 -0.282845 -0.542035  1.060830
# 1970-01-02 00:00:00.020250101 -0.167221 -0.114358  0.570631 -0.874840
# 1970-01-03 00:00:00.020250101 -1.077165  1.489998  0.982820 -0.101213
# 1970-01-04 00:00:00.020250101  1.271209 -0.691593 -0.343296  3.289127
# 1970-01-05 00:00:00.020250101  0.838642 -1.537191 -1.055967 -0.533710
# 1970-01-06 00:00:00.020250101  1.248819 -0.463632 -0.354111 -0.202749
# 1970-01-07 00:00:00.020250101  0.081499  1.460779 -0.918272 -0.471575
# 1970-01-08 00:00:00.020250101  0.525254 -0.381797  0.967154  1.533489
# 1970-01-09 00:00:00.020250101 -0.876179  0.272545 -1.143696 -0.805124
# 1970-01-10 00:00:00.020250101 -1.747875 -0.517902  0.784855  1.709248
# 1970-01-11 00:00:00.020250101  0.105785 -1.143431  0.635537  0.343618
# 1970-01-12 00:00:00.020250101 -1.191874  0.003139 -0.283662 -0.890903
# ...

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2025-01-01  1.0  3  teste  Python
# 1  7 2025-01-01  1.0  3  Train  Python
# 2  7 2025-01-01  1.0  3  Teste  Python
# 3  7 2025-01-01  1.0  3  Train  Python

# %%
# Visualizar dados

df.head(4)
# Out:
#                                       A         B         C         D  \
# 1970-01-01 00:00:00.020250101  0.831664 -0.282845 -0.542035  1.060830
# 1970-01-02 00:00:00.020250101 -0.167221 -0.114358  0.570631 -0.874840
# 1970-01-03 00:00:00.020250101 -1.077165  1.489998  0.982820 -0.101213
# 1970-01-04 00:00:00.020250101  1.271209 -0.691593 -0.343296  3.289127
#
#                                       E  F  G   Produto
# 1970-01-01 00:00:00.020250101 -0.599378  1  0 -0.235232
# 1970-01-02 00:00:00.020250101 -1.329998  1  1  0.019123
# 1970-01-03 00:00:00.020250101  0.233243  1  2 -1.604974
# 1970-01-04 00:00:00.020250101  0.264622  1  3 -0.879158

# %%
df.tail(3) # 3 ultimas linhas
# Out:
#                                       A         B         C         D  \
# 1970-02-27 00:00:00.020250101  0.097355  0.512487 -0.670052 -0.291698
# 1970-02-28 00:00:00.020250101 -0.513475 -1.272229  0.614676 -0.930794
# 1970-03-01 00:00:00.020250101  2.231211 -0.557343 -0.145559 -0.743351
#
#                                       E  F   G   Produto
# 1970-02-27 00:00:00.020250101 -0.592028  1  57  0.049893
# 1970-02-28 00:00:00.020250101 -0.980378  1  58  0.653258
# 1970-03-01 00:00:00.020250101  0.071801  1  59 -1.243549

# %%
df.index
# Out:
# DatetimeIndex(['1970-01-01 00:00:00.020250101',
#                '1970-01-02 00:00:00.020250101',
#                '1970-01-03 00:00:00.020250101',
#                '1970-01-04 00:00:00.020250101',
#                '1970-01-05 00:00:00.020250101',
#                '1970-01-06 00:00:00.020250101',
#                '1970-01-07 00:00:00.020250101',
#                '1970-01-08 00:00:00.020250101',
#                '1970-01-09 00:00:00.020250101',
#                '1970-01-10 00:00:00.020250101',
#                '1970-01-11 00:00:00.020250101',
#                '1970-01-12 00:00:00.020250101',
#                '1970-01-13 00:00:00.020250101',
#                '1970-01-14 00:00:00.020250101',
#                '1970-01-15 00:00:00.020250101',
#                '1970-01-16 00:00:00.020250101',
#                '1970-01-17 00:00:00.020250101',
#                '1970-01-18 00:00:00.020250101',
#                '1970-01-19 00:00:00.020250101',
#                '1970-01-20 00:00:00.020250101',
# ...

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'Produto'], dtype='object')

# %%
c = df.columns # variavel recebe as columns

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2025-01-01  1.0  3  teste  Python
# 1  7 2025-01-01  1.0  3  Train  Python
# 2  7 2025-01-01  1.0  3  Teste  Python
# 3  7 2025-01-01  1.0  3  Train  Python

# %%
df.head(4).to_numpy() # Transforma Dataframe em array/matriz Numpy
# Out:
# array([[ 0.83166429, -0.2828449 , -0.54203506,  1.06083027, -0.59937827,
#          1.        ,  0.        , -0.235232  ],
#        [-0.16722073, -0.11435758,  0.57063105, -0.87483997, -1.32999767,
#          1.        ,  1.        ,  0.01912296],
#        [-1.07716521,  1.48999754,  0.98281978, -0.10121297,  0.23324322,
#          1.        ,  2.        , -1.60497351],
#        [ 1.27120866, -0.69159254, -0.3432963 ,  3.28912728,  0.26462185,
#          1.        ,  3.        , -0.87915842]])

# %%
df.T # Transporta / Álgebra linear -- transforma linhas em colunas e vice-versa
# Out:
#          1970-01-01 00:00:00.020250101  1970-01-02 00:00:00.020250101  \
# A                             0.831664                      -0.167221
# B                            -0.282845                      -0.114358
# C                            -0.542035                       0.570631
# D                             1.060830                      -0.874840
# E                            -0.599378                      -1.329998
# F                             1.000000                       1.000000
# G                             0.000000                       1.000000
# Produto                      -0.235232                       0.019123
#
#          1970-01-03 00:00:00.020250101  1970-01-04 00:00:00.020250101  \
# A                            -1.077165                       1.271209
# B                             1.489998                      -0.691593
# C                             0.982820                      -0.343296
# ...
