# %%
# operadores de desigualdade
3 > 1 and 3 > 2 # and = (e) da lógica
# Out:
# True

# %%
4 > 2 and 4 > 9
# Out:
# False

# %%
3 > 1 or 3 > 2 # or = (ou) da lógica
# Out:
# True

# %%
4 > 2 or 4 > 9
# Out:
# True

# %%
# Operador Lógico de negação
not(3 > 1 or 3 > 2) # o que era True virou False
# Out:
# False

# %%
not(4 > 2 and 4 > 9)
# Out:
# True
