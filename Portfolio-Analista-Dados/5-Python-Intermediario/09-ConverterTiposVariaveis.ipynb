# %%
# Converter Tipos de Variáveis
'''str = em string

int = em inteiro

float = em float
isinstance(2.0, (int,float)) # pergunta se o primeiro argumento/parametro é do tipo do segundo.
'''

isinstance(2.0, int)
# Out:
# False

# %%
isinstance(2.0, (int,float))
# Out:
# True

# %%
isinstance(False, (bool,float))
# Out:
# True

# %%
float(2)
# Out:
# 2.0

# %%
int(3.5)
# Out:
# 3

# %%
str(7)
# Out:
# '7'

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(7)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool("")
# Out:
# False
