# %%
# Indexação em Python começa em [0]

var = "Python"

# %%
type(var)
# Out:
# str

# %%
len(var)
# Out:
# 6

# %%
var[0]
# Out:
# 'P'

# %%
var[3]
# Out:
# 'h'

# %%
var.find("h")
# Out:
# 3

# %%
# Slinsing - Fatiamentos

frase = "Python é uma linguagem muito poderosa!"

frase[0:6]
# Out:
# 'Python'

# %%
frase[ : 12]
# Out:
# 'Python é uma'

# %%
frase[-1]
# Out:
# '!'

# %%
frase[-3]
# Out:
# 's'

# %%
frase[-9:-1]
# Out:
# 'poderosa'

# %%
frase[-1:-9]

frase[::1]
# Out:
# 'Python é uma linguagem muito poderosa!'

# %%
frase[::]
# Out:
# 'Python é uma linguagem muito poderosa!'

# %%
frase[::2]
# Out:
# 'Pto  m igae ut oeoa'
