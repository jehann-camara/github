# %%
import numpy as np

# %%
x = []
y = {}
z = ()

# %%
type(x)
# Out:
# list

# %%
type(y)
# Out:
# dict

# %%
type(z)
# Out:
# tuple

# %%
help("np.random.random()")
# Out:
# No Python documentation found for 'np.random.random()'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
# não funcionou
# ?np.random.randon()
# Out:
# Object `np.random.randon(8)` not found.
